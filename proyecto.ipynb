# %% [raw]
# ---
# title: "Proyecto MN"
# author: "Henry Ramírez, Josune Singaña, Marlon Zurita"
# date: '2023-01-07'
# bibliography: references.bib
# lang: es
# format:
#     pdf:
#         toc: true
#         toc-title: "Tabla de Contenidos"
#         fig-pos: H
# execute:
#     echo: true
#     error: false
#     warning: false
# code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# $$
# h(t)=0.3t^3 - 5t^2 + 21t
# $$

# %%
# %matplotlib ipympl
from sympy import *

x, y, z, t = symbols('x y z t')

print("Solucionador de raíces para la ecuación de la montaña rusa")

error = 1.0
toler = 0.05
i = 0

# Introducir aquí 0.3*x**3 - 5*x**2 + 21*x
print("Introduzca una funcion f(x) y un punto inicial x0:")
funcion = sympify(input("f(x): "))
x0 = sympify(input("x0: "))
toler_b=input("¿Desea ajustar la tolerancia? (Tolerancia defecto = 0.05) y/n: ")

if toler_b == "y":
    toler = float(input("Introduzca un nuevo valor de e: "))
        
funcion_d = diff(funcion, x)

print("Gráfico: ")
p1 = plot(funcion, (x, -100, 100),show=False)
p1.show()

print("Inicio de las iteraciones...")
print(f"Para {funcion} en {x0:.3f} con e = {toler}:")

print("i || x0 || x1 || funcion(x0)/funcion_d(x0) || error")
while error > toler:
    i+=1
    
    x1 = x0 - funcion.subs(x, x0)/funcion_d.subs(x, x0)
    error = abs(x1-x0)
    
    print(f"{i} || {x0:.3f} || {x1:.3f} || {(funcion.subs(x,x0)/funcion_d.subs(x,x0)):.3f} || {error:.3f}")
    x0 = x1
    if(i > 30):
        print("No se encontró ninguna raíz")
        break

print(f"Se encontró una raíz en el punto: {x0:.3f}")
print(f"{funcion} en {x0:.3f} = {funcion.subs(x, x0):.3f}")
# Out:
# Solucionador de raíces para la ecuación de la montaña rusa
# Introduzca una funcion f(x) y un punto inicial x0:
# Gráfico:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Inicio de las iteraciones...
# Para 0.3*x**3 - 5*x**2 + 21*x en 1.000 con e = 0.05:
# i || x0 || x1 || funcion(x0)/funcion_d(x0) || error
# 1 || 1.000 || -0.370 || 1.370 || 1.370
# 2 || -0.370 || -0.029 || -0.341 || 0.341
# 3 || -0.029 || -0.000 || -0.029 || 0.029
# Se encontró una raíz en el punto: -0.000
# 0.3*x**3 - 5*x**2 + 21*x en -0.000 = -0.004

# %% [markdown]
# $$
# h(t)=-0.2t^4+4t^3-24t^2+48t
# $$

# %% [markdown]
# $$
# h(t)=-2t^3+23t^2-59t+24
# $$

# %%
# %matplotlib ipympl
from sympy import *

x, y, z, t = symbols('x y z t')

print("Solucionador de raíces para la ecuación de la montaña rusa")

error = 1.0
toler = 0.05
i = 0

#print("Introduzca una funcion f(x) y un punto inicial x0:")
#funcion = sympify(input("f(x): "))
#x0 = sympify(input("x0: "))

funcion = -0.086*x*(x-2)*(x-3)*(x-6)*(x-8)
x0 = 9

toler_b=input("¿Desea ajustar la tolerancia? (Tolerancia defecto = 0.05) y/n: ")

if toler_b == "y":
    toler = float(input("Introduzca un nuevo valor de e: "))
        
funcion_d = diff(funcion, x)

print("Gráfico: ")
p1 = plot(funcion, (x, -100, 100),xlim=[-50,50], ylim=[-50,50],show=False)
p1.show()

print("Inicio de las iteraciones...")
print(f"Para {funcion} en {x0:.3f} con e = {toler}:")

print("i || x0 || x1 || funcion(x0)/funcion_d(x0) || error")
while error > toler:
    i+=1
    
    x1 = x0 - funcion.subs(x, x0)/funcion_d.subs(x, x0)
    error = abs(x1-x0)
    
    print(f"{i} || {x0:.3f} || {x1:.3f} || {(funcion.subs(x,x0)/funcion_d.subs(x,x0)):.3f} || {error:.3f}")
    x0 = x1
    if(i > 30):
        print("No se encontró ninguna raíz")
        break

print(f"Se encontró una raíz en el punto: {x0:.3f}")
print(f"{funcion} en {x0:.3f} = {funcion.subs(x, x0):.3f}")
# Out:
# Solucionador de raíces para la ecuación de la montaña rusa
# Gráfico:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Inicio de las iteraciones...
# Para -0.086*x*(x - 8)*(x - 6)*(x - 3)*(x - 2) en 9.000 con e = 0.05:
# i || x0 || x1 || funcion(x0)/funcion_d(x0) || error
# 1 || 9.000 || 8.430 || 0.570 || 0.570
# 2 || 8.430 || 8.117 || 0.313 || 0.313
# 3 || 8.117 || 8.012 || 0.105 || 0.105
# 4 || 8.012 || 8.000 || 0.012 || 0.012
# Se encontró una raíz en el punto: 8.000
# -0.086*x*(x - 8)*(x - 6)*(x - 3)*(x - 2) en 8.000 = -0.006
